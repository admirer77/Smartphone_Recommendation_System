# %%
import pandas as pd

# %%
Apple_df = pd.read_csv("..\data\Apple.csv")

Apple_df
# Out:
#                               Name         OS       Price  \
# 0          Apple iPhone 15 Pro Max    iOS v17  Rs.148,900
# 1                  Apple iPhone 15    iOS v17   Rs.70,500
# 2                  Apple iPhone 13    iOS v15   Rs.48,499
# 3                  Apple iPhone 14    iOS v16   Rs.61,200
# 4             Apple iPhone 15 Plus    iOS v17   Rs.79,800
# ..                             ...        ...         ...
# 385          Apple iPhone 11 128GB  iOS v13.0   Rs.45,994
# 386  Apple iPhone 15 Pro Max 512GB    iOS v17  Rs.169,990
# 387     Apple iPhone 15 Plus 256GB    iOS v17   Rs.89,200
# 388    Apple iPhone 15 Pro Max 1TB    iOS v17  Rs.199,900
# 389        Apple iPhone 11 Pro Max  iOS v13.0  Rs.109,900
#
#                                                  Specs 91 mobiles rating
# 0    Hexa Core (3.78 GHz, Dual Core + 2.11 GHz, Qua...               97%
# 1    Hexa Core (3.46 GHz, Dual Core + 2.02 GHz, Qua...               93%
# ...

# %%
Apple_df = Apple_df.drop_duplicates()

Apple_df
# Out:
#                                   Name         OS       Price  \
# 0              Apple iPhone 15 Pro Max    iOS v17  Rs.148,900
# 1                      Apple iPhone 15    iOS v17   Rs.70,500
# 2                      Apple iPhone 13    iOS v15   Rs.48,499
# 3                      Apple iPhone 14    iOS v16   Rs.61,200
# 4                 Apple iPhone 15 Plus    iOS v17   Rs.79,800
# 5                      Apple iPhone 11  iOS v13.0   Rs.43,900
# 6                      Apple iPhone 12    iOS v14   Rs.41,499
# 7                  Apple iPhone 15 Pro    iOS v17  Rs.127,990
# 8                 Apple iPhone 14 Plus    iOS v16   Rs.70,500
# 9              Apple iPhone 12 Pro Max    iOS v14  Rs.119,900
# 20  Apple iPhone SE 2022 (iPhone SE 3)    iOS v15   Rs.30,730
# 21                Apple iPhone 12 Mini    iOS v14   Rs.59,900
# 22                     Apple iPhone XR  iOS v12.0   Rs.47,900
# 23  Apple iPhone SE 2020 (iPhone SE 2)  iOS v13.0   Rs.39,900
# ...

# %%
Oneplus_df = pd.read_csv("..\data\Oneplus.csv")

Oneplus_df
# Out:
#                           Name                              OS      Price  \
# 0         OnePlus Nord CE 4 5G                     Android v14  Rs.24,998
# 1                  OnePlus 12R                     Android v14  Rs.39,999
# 2    OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14  Rs.17,499
# 3                   OnePlus 12                     Android v14  Rs.64,999
# 4         OnePlus Nord CE 3 5G                     Android v13  Rs.20,999
# ..                         ...                             ...        ...
# 385             OnePlus 10 Pro  Android v12, upgradable to v14  Rs.66,999
# 386             OnePlus 10R 5G  Android v12, upgradable to v14  Rs.34,999
# 387                 OnePlus 9R  Android v11, upgradable to v14  Rs.30,999
# 388           OnePlus 12 512GB                     Android v14  Rs.69,998
# 389       OnePlus Nord CE 2 5G  Android v11, upgradable to v12  Rs.23,990
#
#                                                  Specs 91 mobiles rating
# ...

# %%
Oneplus_df = Oneplus_df.drop_duplicates()

Oneplus_df
# Out:
#                                Name                              OS  \
# 0              OnePlus Nord CE 4 5G                     Android v14
# 1                       OnePlus 12R                     Android v14
# 2         OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14
# 3                        OnePlus 12                     Android v14
# 4              OnePlus Nord CE 3 5G                     Android v13
# 5                       OnePlus 11R  Android v13, upgradable to v14
# 6                 OnePlus Nord 3 5G                     Android v13
# 7        OnePlus Nord CE 4 5G 256GB                     Android v14
# 8                 OnePlus 12R 256GB                     Android v14
# 9                        OnePlus 11  Android v13, upgradable to v14
# 20                     OnePlus Open  Android v13, upgradable to v14
# 21               OnePlus Nord 2T 5G  Android v12, upgradable to v14
# 22        OnePlus Nord CE 2 Lite 5G  Android v12, upgradable to v14
# ...

# %%
Realme_df = pd.read_csv("..\data\Realme.csv")

Realme_df
# Out:
#                     Name           OS      Price  \
# 0    realme Narzo 70 Pro  Android v14  Rs.19,999
# 1         realme 12 Plus  Android v14  Rs.19,734
# 2             realme 12x  Android v14  Rs.12,997
# 3              realme P1  Android v14  Rs.15,999
# 4     realme 12 Pro Plus  Android v14  Rs.29,499
# ..                   ...          ...        ...
# 385        realme 11 Pro  Android v13  Rs.23,799
# 386   realme 11 Pro Plus  Android v13  Rs.27,899
# 387           realme C55  Android v13   Rs.9,290
# 388            realme 11  Android v13  Rs.16,999
# 389            realme 10  Android v12  Rs.10,300
#
#                                                  Specs 91 mobiles rating
# 0    Octa core (2.6 GHz, Dual Core + 2 GHz, Hexa Co...               85%
# 1    Octa core (2.6 GHz, Dual Core + 2 GHz, Hexa Co...               84%
# 2    Octa core (2.2 GHz, Dual Core + 2 GHz, Hexa Co...               77%
# 3    Octa core (2.6 GHz, Dual Core + 2 GHz, Hexa Co...               84%
# ...

# %%
Realme_df = Realme_df.drop_duplicates()

Realme_df
# Out:
#                    Name           OS      Price  \
# 0   realme Narzo 70 Pro  Android v14  Rs.19,999
# 1        realme 12 Plus  Android v14  Rs.19,734
# 2            realme 12x  Android v14  Rs.12,997
# 3             realme P1  Android v14  Rs.15,999
# 4    realme 12 Pro Plus  Android v14  Rs.29,499
# 5         realme 12 Pro  Android v14  Rs.22,499
# 6         realme C65 5G  Android v14        NaN
# 7    realme Narzo 60 5G  Android v13  Rs.14,999
# 8   realme Narzo 70x 5G  Android v14  Rs.11,999
# 9      realme P1 Pro 5G  Android v14  Rs.21,999
# 20           realme C53  Android v13   Rs.9,489
# 21  realme Narzo 60X 5G  Android v13  Rs.10,999
# 22        realme C67 5G  Android v13  Rs.12,188
# 23            realme 12  Android v14  Rs.16,889
# 24        realme 11x 5G  Android v13  Rs.14,990
# 25        realme 11 Pro  Android v13  Rs.23,799
# 26   realme 11 Pro Plus  Android v13  Rs.27,899
# 27           realme C55  Android v13   Rs.9,290
# ...

# %%
Realme_df['Price'].fillna("Rs.10,499", inplace=True)

Realme_df
# Out:
# C:\Users\nehan\AppData\Local\Temp\ipykernel_31224\666566050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Realme_df['Price'].fillna("Rs.10,499", inplace=True)
#                    Name           OS      Price  \
# 0   realme Narzo 70 Pro  Android v14  Rs.19,999
# 1        realme 12 Plus  Android v14  Rs.19,734
# 2            realme 12x  Android v14  Rs.12,997
# 3             realme P1  Android v14  Rs.15,999
# 4    realme 12 Pro Plus  Android v14  Rs.29,499
# 5         realme 12 Pro  Android v14  Rs.22,499
# 6         realme C65 5G  Android v14  Rs.10,499
# 7    realme Narzo 60 5G  Android v13  Rs.14,999
# 8   realme Narzo 70x 5G  Android v14  Rs.11,999
# 9      realme P1 Pro 5G  Android v14  Rs.21,999
# 20           realme C53  Android v13   Rs.9,489
# ...

# %%
Redme_df = pd.read_csv("..\data\Redmi.csv")

Redme_df
# Out:
#                                  Name                              OS  \
# 0            Xiaomi Redmi Note 13 Pro  Android v13, upgradable to v14
# 1                Xiaomi Redmi Note 13  Android v13, upgradable to v14
# 2                  Xiaomi Redmi 12 5G                     Android v13
# 3                     Xiaomi 14 Ultra                     Android v14
# 4    Xiaomi Redmi Note 13 Pro Plus 5G  Android v13, upgradable to v14
# ..                                ...                             ...
# 385        Xiaomi Redmi 12 5G 8GB RAM                     Android v13
# 386                 Xiaomi Redmi K50i                     Android v12
# 387          Xiaomi Redmi Note 11 Pro                     Android v11
# 388        Xiaomi Redmi Note 13 256GB  Android v13, upgradable to v14
# 389                   Xiaomi Redmi A3                     Android v13
#
#          Price                                              Specs  \
# ...

# %%
Redme_df = Redme_df.drop_duplicates()

Redme_df
# Out:
#                                 Name                              OS  \
# 0           Xiaomi Redmi Note 13 Pro  Android v13, upgradable to v14
# 1               Xiaomi Redmi Note 13  Android v13, upgradable to v14
# 2                 Xiaomi Redmi 12 5G                     Android v13
# 3                    Xiaomi 14 Ultra                     Android v14
# 4   Xiaomi Redmi Note 13 Pro Plus 5G  Android v13, upgradable to v14
# 5                          Xiaomi 14                     Android v14
# 6                Xiaomi Redmi 13C 5G                     Android v13
# 7                   Xiaomi Redmi 13C                     Android v13
# 8               Xiaomi Redmi Note 12  Android v12, upgradable to v14
# 9            Xiaomi Redmi Note 12 4G                     Android v13
# 20       Xiaomi Redmi Note 12 Pro 5G                     Android v12
# 21                  Xiaomi Redmi 12C                     Android v12
# 22  Xiaomi Redmi Note 12 Pro Plus 5G                     Android v12
# ...

# %%
Samsung_df = pd.read_csv("..\data\Samsung.csv")

Samsung_df
# Out:
#                                Name                              OS  \
# 0             Samsung Galaxy M55 5G                     Android v14
# 1          Samsung Galaxy S24 Ultra                     Android v14
# 2             Samsung Galaxy A55 5G                     Android v14
# 3             Samsung Galaxy A35 5G                     Android v14
# 4                Samsung Galaxy F15                     Android v14
# ..                              ...                             ...
# 385      Samsung Galaxy S24 Plus 5G                     Android v14
# 386           Samsung Galaxy A54 5G                     Android v13
# 387  Samsung Galaxy S24 Ultra 512GB                     Android v14
# 388              Samsung Galaxy M14                     Android v13
# 389      Samsung Galaxy S21 FE 2023  Android v13, upgradable to v14
#
#           Price                                              Specs  \
# 0     Rs.24,999  Octa core (2.4 GHz, Single Core + 2.36 GHz, Tr...
# ...

# %%
Samsung_df = Samsung_df.drop_duplicates()

Samsung_df
# Out:
#                               Name                              OS  \
# 0            Samsung Galaxy M55 5G                     Android v14
# 1         Samsung Galaxy S24 Ultra                     Android v14
# 2            Samsung Galaxy A55 5G                     Android v14
# 3            Samsung Galaxy A35 5G                     Android v14
# 4               Samsung Galaxy F15                     Android v14
# 5            Samsung Galaxy F54 5G  Android v13, upgradable to v14
# 6               Samsung Galaxy M34  Android v13, upgradable to v14
# 7            Samsung Galaxy S24 5G                     Android v14
# 8            Samsung Galaxy A15 5G                     Android v14
# 9            Samsung Galaxy S23 FE  Android v13, upgradable to v14
# 20           Samsung Galaxy S23 5G  Android v13, upgradable to v14
# 21              Samsung Galaxy S22  Android v12, upgradable to v14
# 22           Samsung Galaxy A14 5G  Android v13, upgradable to v14
# ...

# %%
Vivo_df = pd.read_csv("..\data\Vivo.csv")

Vivo_df
# Out:
#                    Name                              OS      Price  \
# 0              vivo V30                     Android v14  Rs.31,580
# 1               vivo T3                     Android v14  Rs.19,999
# 2              vivo T3x                     Android v14  Rs.13,499
# 3              vivo V29                     Android v13  Rs.31,999
# 4             vivo V29e                     Android v13  Rs.24,499
# ..                  ...                             ...        ...
# 385           vivo X100                     Android v14  Rs.63,999
# 386    vivo T2x 6GB RAM                     Android v13  Rs.12,999
# 387            vivo Y36                     Android v13  Rs.12,749
# 388        vivo V27 Pro  Android v13, upgradable to v14  Rs.34,999
# 389  vivo V30 Pro 512GB                     Android v14  Rs.46,999
#
#                                                  Specs 91 mobiles rating
# 0    Octa core (2.63 GHz, Single Core + 2.4 GHz, Tr...               83%
# ...

# %%
Vivo_df = Vivo_df.drop_duplicates()

# %%
Android_df = pd.concat([Oneplus_df, Realme_df, Redme_df, Samsung_df, Vivo_df], ignore_index=True)

# If you want to reset the index of the combined dataframe
Android_df.reset_index(drop=True, inplace=True)

Android_df
# Out:
#                          Name                              OS      Price  \
# 0        OnePlus Nord CE 4 5G                     Android v14  Rs.24,998
# 1                 OnePlus 12R                     Android v14  Rs.39,999
# 2   OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14  Rs.17,499
# 3                  OnePlus 12                     Android v14  Rs.64,999
# 4        OnePlus Nord CE 3 5G                     Android v13  Rs.20,999
# ..                        ...                             ...        ...
# 95                  vivo X100                     Android v14  Rs.63,999
# 96           vivo T2x 6GB RAM                     Android v13  Rs.12,999
# 97                   vivo Y36                     Android v13  Rs.12,749
# 98               vivo V27 Pro  Android v13, upgradable to v14  Rs.34,999
# 99         vivo V30 Pro 512GB                     Android v14  Rs.46,999
#
#                                                 Specs 91 mobiles rating
# ...

# %%
Android_df['Price'] = Android_df['Price'].str.replace('Rs.', '').str.replace(',', '')

# %%
Android_df
# Out:
#                          Name                              OS  Price  \
# 0        OnePlus Nord CE 4 5G                     Android v14  24998
# 1                 OnePlus 12R                     Android v14  39999
# 2   OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14  17499
# 3                  OnePlus 12                     Android v14  64999
# 4        OnePlus Nord CE 3 5G                     Android v13  20999
# ..                        ...                             ...    ...
# 95                  vivo X100                     Android v14  63999
# 96           vivo T2x 6GB RAM                     Android v13  12999
# 97                   vivo Y36                     Android v13  12749
# 98               vivo V27 Pro  Android v13, upgradable to v14  34999
# 99         vivo V30 Pro 512GB                     Android v14  46999
#
#                                                 Specs 91 mobiles rating
# ...

# %%
Android_df['91 mobiles rating'] = Android_df['91 mobiles rating'].str.replace('%', '')

# %%
Android_df['91 mobiles rating'] = pd.to_numeric(Android_df['91 mobiles rating']) / 10

# %%
Android_df
# Out:
#                          Name                              OS  Price  \
# 0        OnePlus Nord CE 4 5G                     Android v14  24998
# 1                 OnePlus 12R                     Android v14  39999
# 2   OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14  17499
# 3                  OnePlus 12                     Android v14  64999
# 4        OnePlus Nord CE 3 5G                     Android v13  20999
# ..                        ...                             ...    ...
# 95                  vivo X100                     Android v14  63999
# 96           vivo T2x 6GB RAM                     Android v13  12999
# 97                   vivo Y36                     Android v13  12749
# 98               vivo V27 Pro  Android v13, upgradable to v14  34999
# 99         vivo V30 Pro 512GB                     Android v14  46999
#
#                                                 Specs  91 mobiles rating
# ...

# %%
Android_df_1 = Android_df['Specs'].str.split('\n', expand=True)

column_names = ['Core','Processor', 'RAM','Empty3', 'Display Size', 'Display Type', 'Refresh Rate','Empty', 'Camera Details', 'Flash Type','Screen flash','Empty2','Battery','Fast charging', 'Type-C']
Android_df_1.columns = column_names
Android_df_1 = Android_df_1.drop(columns=['Empty3','Empty','Empty2'])

Android_df_1
# Out:
#                                                  Core  \
# 0   Octa core (2.63 GHz, Single Core + 2.4 GHz, Tr...
# 1   Octa core (3.2 GHz, Single Core + 2.8 GHz, Qua...
# 2   Octa core (2.2 GHz, Dual Core + 1.7 GHz, Hexa ...
# 3   Octa core (3.3 GHz, Single Core + 3.2 GHz, Pen...
# 4   Octa core (2.7 GHz, Single Core + 2.2 GHz, Tri...
# ..                                                ...
# 95  Octa core (3.25 GHz, Single Core + 2.85 GHz, T...
# 96  Octa core (2.2 GHz, Dual Core + 2 GHz, Hexa Co...
# 97  Octa core (2.4 GHz, Quad Core + 1.9 GHz, Quad ...
# 98  Octa core (3.1 GHz, Single Core + 3 GHz, Tri c...
# 99  Octa core (3.1 GHz, Single Core + 3 GHz, Tri c...
#
#                   Processor        RAM            Display Size  \
# 0        Snapdragon 7 Gen 3   8 GB RAM   6.7 inches (17.02 cm)
# 1        Snapdragon 8 Gen 2   8 GB RAM  6.78 inches (17.22 cm)
# 2            Snapdragon 695   8 GB RAM  6.72 inches (17.07 cm)
# ...

# %%
Android_df = pd.concat([Android_df, Android_df_1], axis=1)

Android_df
# Out:
#                          Name                              OS  Price  \
# 0        OnePlus Nord CE 4 5G                     Android v14  24998
# 1                 OnePlus 12R                     Android v14  39999
# 2   OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14  17499
# 3                  OnePlus 12                     Android v14  64999
# 4        OnePlus Nord CE 3 5G                     Android v13  20999
# ..                        ...                             ...    ...
# 95                  vivo X100                     Android v14  63999
# 96           vivo T2x 6GB RAM                     Android v13  12999
# 97                   vivo Y36                     Android v13  12749
# 98               vivo V27 Pro  Android v13, upgradable to v14  34999
# 99         vivo V30 Pro 512GB                     Android v14  46999
#
#                                                 Specs  91 mobiles rating  \
# ...

# %%
Android_df = Android_df.drop(columns=['Specs'])

Android_df
# Out:
#                          Name                              OS  Price  \
# 0        OnePlus Nord CE 4 5G                     Android v14  24998
# 1                 OnePlus 12R                     Android v14  39999
# 2   OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14  17499
# 3                  OnePlus 12                     Android v14  64999
# 4        OnePlus Nord CE 3 5G                     Android v13  20999
# ..                        ...                             ...    ...
# 95                  vivo X100                     Android v14  63999
# 96           vivo T2x 6GB RAM                     Android v13  12999
# 97                   vivo Y36                     Android v13  12749
# 98               vivo V27 Pro  Android v13, upgradable to v14  34999
# 99         vivo V30 Pro 512GB                     Android v14  46999
#
#     91 mobiles rating                                               Core  \
# ...

# %%
Android_df.to_csv("Android_mobiles.csv")

# %%
Apple_df_1 = Apple_df['Specs'].str.split('\n', expand=True)

column_names = ['Core','Processor', 'RAM','Empty3', 'Display Size', 'Display Type', 'Refresh Rate','Empty', 'Camera Details', 'Flash Type','Screen flash','Empty2','Battery','Fast charging', 'Type-C']
Apple_df_1.columns = column_names
Apple_df_1 = Apple_df_1.drop(columns=['Empty3','Empty','Empty2'])

Apple_df_1
# Out:
#                                                  Core         Processor  \
# 0   Hexa Core (3.78 GHz, Dual Core + 2.11 GHz, Qua...     Apple A17 Pro
# 1   Hexa Core (3.46 GHz, Dual Core + 2.02 GHz, Qua...  Apple A16 Bionic
# 2   Hexa Core (3.23 GHz, Dual Core + 1.82 GHz, Qua...  Apple A15 Bionic
# 3   Hexa Core (3.23 GHz, Dual Core + 1.82 GHz, Qua...  Apple A15 Bionic
# 4   Hexa Core (3.46 GHz, Dual Core + 2.02 GHz, Qua...  Apple A16 Bionic
# 5   Hexa Core (2.65 GHz, Dual Core + 1.8 GHz, Quad...  Apple A13 Bionic
# 6   Hexa Core (3.1 GHz, Dual Core + 1.8 GHz, Quad ...  Apple A14 Bionic
# 7   Hexa Core (3.78 GHz, Dual Core + 2.11 GHz, Qua...     Apple A17 Pro
# 8   Hexa Core (3.23 GHz, Dual Core + 1.82 GHz, Qua...  Apple A15 Bionic
# 9   Hexa Core (3.1 GHz, Dual Core + 1.8 GHz, Quad ...  Apple A14 Bionic
# 20  Hexa Core (3.23 GHz, Dual Core + 1.82 GHz, Qua...  Apple A15 Bionic
# 21  Hexa Core (3.1 GHz, Dual Core + 1.8 GHz, Quad ...  Apple A14 Bionic
# ...

# %%
Apple_df['91 mobiles rating'] = Apple_df['91 mobiles rating'].str.replace('%', '')
# Out:
# C:\Users\nehan\AppData\Local\Temp\ipykernel_31224\2367410875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Apple_df['91 mobiles rating'] = Apple_df['91 mobiles rating'].str.replace('%', '')

# %%
Apple_df['91 mobiles rating'] = pd.to_numeric(Apple_df['91 mobiles rating']) / 10
# Out:
# C:\Users\nehan\AppData\Local\Temp\ipykernel_31224\2549023265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Apple_df['91 mobiles rating'] = pd.to_numeric(Apple_df['91 mobiles rating']) / 10

# %%
Apple_df
# Out:
#                                   Name         OS       Price  \
# 0              Apple iPhone 15 Pro Max    iOS v17  Rs.148,900
# 1                      Apple iPhone 15    iOS v17   Rs.70,500
# 2                      Apple iPhone 13    iOS v15   Rs.48,499
# 3                      Apple iPhone 14    iOS v16   Rs.61,200
# 4                 Apple iPhone 15 Plus    iOS v17   Rs.79,800
# 5                      Apple iPhone 11  iOS v13.0   Rs.43,900
# 6                      Apple iPhone 12    iOS v14   Rs.41,499
# 7                  Apple iPhone 15 Pro    iOS v17  Rs.127,990
# 8                 Apple iPhone 14 Plus    iOS v16   Rs.70,500
# 9              Apple iPhone 12 Pro Max    iOS v14  Rs.119,900
# 20  Apple iPhone SE 2022 (iPhone SE 3)    iOS v15   Rs.30,730
# 21                Apple iPhone 12 Mini    iOS v14   Rs.59,900
# 22                     Apple iPhone XR  iOS v12.0   Rs.47,900
# 23  Apple iPhone SE 2020 (iPhone SE 2)  iOS v13.0   Rs.39,900
# ...

# %%
Apple_df = pd.concat([Apple_df, Apple_df_1], axis=1)

Apple_df
# Out:
#                                   Name         OS       Price  \
# 0              Apple iPhone 15 Pro Max    iOS v17  Rs.148,900
# 1                      Apple iPhone 15    iOS v17   Rs.70,500
# 2                      Apple iPhone 13    iOS v15   Rs.48,499
# 3                      Apple iPhone 14    iOS v16   Rs.61,200
# 4                 Apple iPhone 15 Plus    iOS v17   Rs.79,800
# 5                      Apple iPhone 11  iOS v13.0   Rs.43,900
# 6                      Apple iPhone 12    iOS v14   Rs.41,499
# 7                  Apple iPhone 15 Pro    iOS v17  Rs.127,990
# 8                 Apple iPhone 14 Plus    iOS v16   Rs.70,500
# 9              Apple iPhone 12 Pro Max    iOS v14  Rs.119,900
# 20  Apple iPhone SE 2022 (iPhone SE 3)    iOS v15   Rs.30,730
# 21                Apple iPhone 12 Mini    iOS v14   Rs.59,900
# 22                     Apple iPhone XR  iOS v12.0   Rs.47,900
# 23  Apple iPhone SE 2020 (iPhone SE 2)  iOS v13.0   Rs.39,900
# ...

# %%
Apple_df = Apple_df.reset_index()
Apple_df = Apple_df.drop(columns=['index'])
Apple_df
# Out:
#                                   Name         OS       Price  \
# 0              Apple iPhone 15 Pro Max    iOS v17  Rs.148,900
# 1                      Apple iPhone 15    iOS v17   Rs.70,500
# 2                      Apple iPhone 13    iOS v15   Rs.48,499
# 3                      Apple iPhone 14    iOS v16   Rs.61,200
# 4                 Apple iPhone 15 Plus    iOS v17   Rs.79,800
# 5                      Apple iPhone 11  iOS v13.0   Rs.43,900
# 6                      Apple iPhone 12    iOS v14   Rs.41,499
# 7                  Apple iPhone 15 Pro    iOS v17  Rs.127,990
# 8                 Apple iPhone 14 Plus    iOS v16   Rs.70,500
# 9              Apple iPhone 12 Pro Max    iOS v14  Rs.119,900
# 10  Apple iPhone SE 2022 (iPhone SE 3)    iOS v15   Rs.30,730
# 11                Apple iPhone 12 Mini    iOS v14   Rs.59,900
# 12                     Apple iPhone XR  iOS v12.0   Rs.47,900
# 13  Apple iPhone SE 2020 (iPhone SE 2)  iOS v13.0   Rs.39,900
# ...

# %%
Apple_df = Apple_df.drop(columns=['Specs'])

Apple_df
# Out:
#                                   Name         OS       Price  \
# 0              Apple iPhone 15 Pro Max    iOS v17  Rs.148,900
# 1                      Apple iPhone 15    iOS v17   Rs.70,500
# 2                      Apple iPhone 13    iOS v15   Rs.48,499
# 3                      Apple iPhone 14    iOS v16   Rs.61,200
# 4                 Apple iPhone 15 Plus    iOS v17   Rs.79,800
# 5                      Apple iPhone 11  iOS v13.0   Rs.43,900
# 6                      Apple iPhone 12    iOS v14   Rs.41,499
# 7                  Apple iPhone 15 Pro    iOS v17  Rs.127,990
# 8                 Apple iPhone 14 Plus    iOS v16   Rs.70,500
# 9              Apple iPhone 12 Pro Max    iOS v14  Rs.119,900
# 10  Apple iPhone SE 2022 (iPhone SE 3)    iOS v15   Rs.30,730
# 11                Apple iPhone 12 Mini    iOS v14   Rs.59,900
# 12                     Apple iPhone XR  iOS v12.0   Rs.47,900
# 13  Apple iPhone SE 2020 (iPhone SE 2)  iOS v13.0   Rs.39,900
# ...

# %%
# Apple_df.to_csv("Apple_mobiles.csv")
