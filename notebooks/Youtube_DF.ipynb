# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime, timezone
import time  # Import the time module

# %%
# Set up API key and build the API client
API_KEY = 'AIzaSyBbaDinbiKs5Um-y1js9ivL-8afp53NvUA'
youtube = build('youtube', 'v3', developerKey=API_KEY)

# %%
smartphones_df = pd.read_csv('M:\Pat_Mini_Project\data\OS\Android_mobiles.csv')

smartphones_df
# Out:
#     Unnamed: 0                       Name                              OS  \
# 0            0       OnePlus Nord CE 4 5G                     Android v14
# 1            1                OnePlus 12R                     Android v14
# 2            2  OnePlus Nord CE 3 Lite 5G  Android v13, upgradable to v14
# 3            3                 OnePlus 12                     Android v14
# 4            4       OnePlus Nord CE 3 5G                     Android v13
# ..         ...                        ...                             ...
# 95          95                  vivo X100                     Android v14
# 96          96           vivo T2x 6GB RAM                     Android v13
# 97          97                   vivo Y36                     Android v13
# 98          98               vivo V27 Pro  Android v13, upgradable to v14
# 99          99         vivo V30 Pro 512GB                     Android v14
#
#     Price  91 mobiles rating  \
# 0   24998                8.6
# ...

# %%
# Define search parameters
order = 'relevance'  # Other options: 'rating', 'viewCount', 'date', etc.

# %%
next_page_token = None
videos = []

# %%
for i in range(100):
    smartphone = smartphones_df["Name"][i]
    query = f'{smartphone} review PrasadTechinTelugu'

    search_response = youtube.search().list(
        q=query,
        part='snippet',
        type='video',
        maxResults = 2,
        order=order
    ).execute()

    video_ids = [item['id']['videoId'] for item in search_response['items']]

    for video_id in video_ids:
        video_response = youtube.videos().list(
            part='snippet,statistics',
            id=video_id
        ).execute()

        video_details = video_response['items'][0]
        statistics = video_details.get('statistics', {})
        likes = statistics.get('likeCount', 0)  # Default to 0 if likeCount is missing

        videos.append({
            'Title': video_details['snippet']['title'],
            'Video ID': video_id,
            'Channel': video_details['snippet']['channelTitle'],
            'Published At': video_details['snippet']['publishedAt'],
            'Views': statistics.get('viewCount', 0),  # Default to 0 if viewCount is missing
            'Likes': likes,
            'smartphone Name': smartphone
        })

# %%
videos_df = pd.DataFrame(videos)
videos_df
# Out:
#                                                  Title     Video ID  \
# 0    OnePlus NORD CE4  Unboxing & Quick Review || i...  QBBHJfDpGVQ
# 1    Tech News 1723 || OnePlus Nord CE4 Launch,Poco...  6rry_NwFktY
# 2                Oneplus 12R 5G Review || in Telugu ||  mzHiV0BrAz8
# 3    OnePlus 12R Genshin Impact Special Edition Unb...  2Wh_WOhbVPc
# 4    OnePlus Nord CE3 Lite 5G & OnePlus Nord Buds 2...  _UoLDxUH9BU
# ..                                                 ...          ...
# 241  Vivo Y36 Quick Unboxing and Best Review || In ...  0ODe481uUR8
# 242  vivo V27 Pro Unboxing & intial impressions ll ...  Tr9JgixHP0Q
# 243  vivo V27 & vivo TWS Air unboxing & initial imp...  bxicMhJrdVo
# 244  vivo V30 Series Unboxing & initial impressions...  o9nwz2Cmw10
# 245  Tech News 1705 || Google Pixel 8A, Vivo V30 Se...  JFRe9ztx0S8
#
#                   Channel          Published At    Views  Likes  \
# 0      Prasadtechintelugu  2024-04-06T14:32:08Z   318011  19154
# ...

# %%
videos_df = videos_df.drop_duplicates()

videos_df
# Out:
#                                                  Title     Video ID  \
# 0    OnePlus NORD CE4  Unboxing & Quick Review || i...  QBBHJfDpGVQ
# 1    Tech News 1723 || OnePlus Nord CE4 Launch,Poco...  6rry_NwFktY
# 2                Oneplus 12R 5G Review || in Telugu ||  mzHiV0BrAz8
# 3    OnePlus 12R Genshin Impact Special Edition Unb...  2Wh_WOhbVPc
# 4    OnePlus Nord CE3 Lite 5G & OnePlus Nord Buds 2...  _UoLDxUH9BU
# ..                                                 ...          ...
# 241  Vivo Y36 Quick Unboxing and Best Review || In ...  0ODe481uUR8
# 242  vivo V27 Pro Unboxing & intial impressions ll ...  Tr9JgixHP0Q
# 243  vivo V27 & vivo TWS Air unboxing & initial imp...  bxicMhJrdVo
# 244  vivo V30 Series Unboxing & initial impressions...  o9nwz2Cmw10
# 245  Tech News 1705 || Google Pixel 8A, Vivo V30 Se...  JFRe9ztx0S8
#
#                   Channel          Published At    Views  Likes  \
# 0      Prasadtechintelugu  2024-04-06T14:32:08Z   318011  19154
# ...

# %%
videos_df.shape
# Out:
# (246, 7)

# %%
videos_df.to_csv("youtube_android_review.csv")

# %%
Apple_df = pd.read_csv('M:\Pat_Mini_Project\data\OS\Apple_mobiles.csv')

Apple_df
# Out:
#     Unnamed: 0                                Name         OS       Price  \
# 0            0             Apple iPhone 15 Pro Max    iOS v17  Rs.148,900
# 1            1                     Apple iPhone 15    iOS v17   Rs.70,500
# 2            2                     Apple iPhone 13    iOS v15   Rs.48,499
# 3            3                     Apple iPhone 14    iOS v16   Rs.61,200
# 4            4                Apple iPhone 15 Plus    iOS v17   Rs.79,800
# 5            5                     Apple iPhone 11  iOS v13.0   Rs.43,900
# 6            6                     Apple iPhone 12    iOS v14   Rs.41,499
# 7            7                 Apple iPhone 15 Pro    iOS v17  Rs.127,990
# 8            8                Apple iPhone 14 Plus    iOS v16   Rs.70,500
# 9            9             Apple iPhone 12 Pro Max    iOS v14  Rs.119,900
# 10          10  Apple iPhone SE 2022 (iPhone SE 3)    iOS v15   Rs.30,730
# 11          11                Apple iPhone 12 Mini    iOS v14   Rs.59,900
# ...

# %%
videos_ = []

# %%
for i in range(20):
    smartphone = Apple_df["Name"][i]
    query = f'{smartphone} review PrasadTechinTelugu'

    search_response = youtube.search().list(
        q=query,
        part='snippet',
        type='video',
        maxResults = 2,
        order=order
    ).execute()

    video_ids = [item['id']['videoId'] for item in search_response['items']]

    for video_id in video_ids:
        video_response = youtube.videos().list(
            part='snippet,statistics',
            id=video_id
        ).execute()

        video_details = video_response['items'][0]
        statistics = video_details.get('statistics', {})
        likes = statistics.get('likeCount', 0)  # Default to 0 if likeCount is missing

        videos_.append({
            'Title': video_details['snippet']['title'],
            'Video ID': video_id,
            'Channel': video_details['snippet']['channelTitle'],
            'Published At': video_details['snippet']['publishedAt'],
            'Views': statistics.get('viewCount', 0),  # Default to 0 if viewCount is missing
            'Likes': likes,
            'smartphone Name': smartphone
        })

# %%
Apple_videos_df = pd.DataFrame(videos_)
Apple_videos_df
# Out:
#                                                 Title     Video ID  \
# 0   iPhone 15 Series Unboxing & initial impression...  VHDs_oodK8k
# 1   Apple Event 2023  || Ft. iPhone 15 Series, App...  UBsjBYNWtSs
# 2   iPhone 15 Series Unboxing & initial impression...  VHDs_oodK8k
# 3   iPhone 15 Series : What we know so far ll in T...  xWKOM05I4ZI
# 4   Apple iphone 13 Series Unboxing & initial Impr...  fCQH6BTULiU
# 5                   Shot On iphone 13 || in Telugu ||  fekDZ-CYFm4
# 6   iPhone 14 Unboxing || Compared With iPhone 13 ...  uRPkjFOJoCU
# 7   iPhone 14 Plus Unboxing & initial impressions ...  WXZ8oxBaIkY
# 8   iPhone 15 Series Unboxing & initial impression...  VHDs_oodK8k
# 9   Apple Event 2023  || Ft. iPhone 15 Series, App...  UBsjBYNWtSs
# 10   సేల్స్ లో ఏ iphone కొనాలి ? || September 2022 ll  4mcFzK13IkU
# 11     సేల్స్ లో ఏ iphone కొనాలి ? || October 2023 ll  h5SkFwN_0jQ
# 12  Apple iPhone 12 & 12 Pro Unboxing ll in Telugu ll  0ZYB_uDUozA
# ...

# %%
Apple_videos_df.to_csv("youtube_apple_review.csv")
