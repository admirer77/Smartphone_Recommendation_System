# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
# Set up API key and build the API client
API_KEY = 'AIzaSyBdLde5uSMyq0AnQU_6j8K-GE9rpwqTiog'
youtube = build('youtube', 'v3', developerKey=API_KEY)

# %%
# Define search parameters
query = 'Prasad Tech in Telugu single mobile review launched in 2024'
max_results = 50  # Adjust as needed
order = 'relevance'  # Other options: 'rating', 'viewCount', 'date', etc.

# %%
search_response = youtube.search().list(
    q=query,
    part='snippet',
    type='video',
    maxResults=max_results,
    order=order
).execute()

# %%
video_ids = [item['id']['videoId'] for item in search_response['items']]

videos = []

# %%
for video_id in video_ids:
    video_response = youtube.videos().list(
        part='snippet,statistics',
        id=video_id
    ).execute()

    video_details = video_response['items'][0]
    try:
        dislikes = video_details['statistics']['dislikeCount']
    except KeyError:
        dislikes = 0  # Set default value if dislikeCount is missing

    videos.append({
        'Title': video_details['snippet']['title'],
        'Video ID': video_id,
        'Channel': video_details['snippet']['channelTitle'],
        'Published At': video_details['snippet']['publishedAt'],
        'Views': video_details['statistics']['viewCount'],
        'Likes': video_details['statistics']['likeCount'],
    })

# %%
videos_df = pd.DataFrame(videos)
videos_df
# Out:
#                                                 Title     Video ID  \
# 0   CES 2024 Highlights in Telugu|| Prasad Tech in...  dOaoInSCzjY
# 1   iQOO Neo 9 Pro vs Oneplus 12R ఏది కొనాలి ? || ...  CNZea3vs774
# 2   Upcoming Mobiles Phones in May 2024 || మే నెలల...  FasaSW5i9VU
# 3   Best Air coolers  2024  || Air Cooler Buying G...  qiowW015WWE
# 4   Youtuber Prasad Tech Speech @ Telugu DMF #Orig...  F26kO7o0jaE
# 5   Best Gaming Phones To Buy May 2022 || in Telug...  tTCWLeBVHd8
# 6   5G మొబైల్ కొనే ముందు ఈ వీడియో చూడండి || Prasad...  M5l8BS9ZrMI
# 7   Lava AGNI 2 5G 🔥 Unboxing & initial Impression...  FcP8dmGV6sI
# 8   This is a Special Phone⚡ || Unboxing Harrypott...  WBd9cYMivxs
# 9   Under Rs 30000 Top Smartphone Deals in MAY 202...  G_uVa7zK9LA
# 10  Best Mobiles Under 20,000 || Which Mobile Is B...  _w4AWHuJu_o
# 11  MIVI Fort S100 & S60 Soundbar with inbuilt Sub...  19RCpTRFocY
# 12  కొత్త ఫోన్ 📦 కొంటే వెంటనే ఈ పనులు చేయండి 😎 || ...  OEPVUhfj7Xg
# ...

# %%
videos_df.shape
# Out:
# (50, 6)
